# %%
# Import of libraries

# System libraries
import re
import unicodedata
import itertools

# Library for file manipulation
import pandas as pd
import numpy as np
import pandas

# Data visualization
import seaborn as sns
import matplotlib.pylab as pl
import matplotlib as m
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly.express as px
from matplotlib import pyplot as plt

# %% [markdown]
# # Importation

# %%
# Load the dataset "Studies to monitor potential adaptations" into a DataFrame
data_1 = pd.read_csv("/home/cytech/Rag_covid/data/Kaggle/target_tables/4_models_and_open_questions/Studies to monitor potential adaptations.csv")

# Load the dataset "What is known about adaptations (mutations) of the virus" into a DataFrame
data_2 = pd.read_csv("/home/cytech/Rag_covid/data/Kaggle/target_tables/4_models_and_open_questions/What is known about adaptations (mutations) of the virus_.csv")

# Load the dataset "Diagnosing SARS-COV-2 with antibodies" into a DataFrame
data_3 = pd.read_csv("/home/cytech/Rag_covid/data/Kaggle/target_tables/6_diagnostics/Diagnosing SARS-COV-2 with antibodies.csv")

# %%
# Display the first five rows of the dataset "Studies to monitor potential adaptations"
data_1.head()
# Out:
#    Unnamed: 0        Date                                              Study  \
# 0           0  2020-04-24  STAT2 signaling as double-edged sword restrict...
# 1           1  2020-04-20  SARS-coronavirus-2 replication in Vero E6 cell...
# 2           2  2020-04-18  Coronavirus Infection and PARP Expression Dysr...
# 3           3  2020-04-17  Distinct early IgA profile may determine sever...
# 4           4  2020-03-23  Potential Factors for Prediction of Disease Se...
#
#                                     Study Link  Journal  \
# 0    https://doi.org/10.1101/2020.04.23.056838  biorxiv
# 1    https://doi.org/10.1101/2020.04.20.049924  biorxiv
# 2    https://doi.org/10.1101/2020.04.17.047480  biorxiv
# 3  https://doi.org/10.1101/2020.04.14.20059733  medRxiv
# 4  https://doi.org/10.1101/2020.03.20.20039818  medRxiv
#
#                               Method  \
# 0                            RT qPCR
# 1                   Genomic Analysis
# 2              Western Blot Analysis
# ...

# %%
# Display the last five rows of the dataset "Studies to monitor potential adaptations"
data_1.tail()
# Out:
#     Unnamed: 0        Date                                              Study  \
# 9            9  2020-02-17  Optimizing diagnostic strategy for novel coron...
# 10          10  2020-02-14  Current Trends in Diagnostics of Viral Infecti...
# 11          11  2020-02-12  The immune vulnerability landscape of the 2019...
# 12          12  2020-02-11  The Essential Facts of Wuhan Novel Coronavirus...
# 13          13  2020-01-31  2019-nCoV: The Identify-Isolate-Inform (3I) To...
#
#                                            Study Link           Journal  \
# 9         https://doi.org/10.1101/2020.02.13.20022673           medrxiv
# 10  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...      MDPI Viruses
# 11          https://doi.org/10.1101/2020.02.08.939553           biorxiv
# 12  https://www.biorxiv.org/content/10.1101/2020.0...           biorxiv
# 13  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...  West J Emerg Med
#
#                                             Method  \
# ...

# %%
# Display a concise summary of the dataset, including column types and non-null values
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           14 non-null     int64
#  1   Date                 14 non-null     object
#  2   Study                14 non-null     object
#  3   Study Link           14 non-null     object
#  4   Journal              14 non-null     object
#  5   Method               14 non-null     object
#  6   Result               14 non-null     object
#  7   Measure of Evidence  14 non-null     object
#  8   Added on             14 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 1.1+ KB

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           19 non-null     int64
#  1   Date                 19 non-null     object
#  2   Study                19 non-null     object
#  3   Study Link           19 non-null     object
#  4   Journal              19 non-null     object
#  5   Method               18 non-null     object
#  6   Result               19 non-null     object
#  7   Measure of Evidence  19 non-null     object
#  8   Added on             19 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 1.5+ KB

# %%
data_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   34 non-null     int64
#  1   Date                         34 non-null     object
#  2   Study                        34 non-null     object
#  3   Study Link                   34 non-null     object
#  4   Journal                      34 non-null     object
#  5   Study Type                   34 non-null     object
#  6   Detection Method             34 non-null     object
#  7   Sample Size                  34 non-null     object
#  8   Measure of Testing Accuracy  34 non-null     object
#  9   Speed of assay               31 non-null     object
#  10  FDA approval (Y/N)           32 non-null     object
#  11  Added on                     34 non-null     object
# dtypes: int64(1), object(11)
# memory usage: 3.3+ KB

# %%
# Display the shape of the dataset (number of rows and columns)
print(data_1.shape)
print(data_2.shape)
print(data_3.shape)
# Out:
# (14, 9)
# (19, 9)
# (34, 12)
